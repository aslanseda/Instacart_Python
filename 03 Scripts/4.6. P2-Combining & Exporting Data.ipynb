# %% [markdown]
# # Contents
# ## 1. Importing Libraries
# ## 2. Importing Data Frames
# ## 3. Checking the Datasets
# ## 4. Cleaning the datasets
# ## 5. Merging the datasets
# ## 6. Exporting the dataset

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing Data Frames

# %%
# Creating the path for the data
path = r'C:\Users\sdaon\Documents\Instacart Basket Analysis'

# %%
# Importing orders_products_combined
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Importing products data
df_prods_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'prods_checked.csv'), index_col = False)

# %% [markdown]
# # 3. Checking the Datasets

# %%
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
orders_products_combined.head(50)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            0   2539329        1             1                   2
# 2            0   2539329        1             1                   2
# 3            0   2539329        1             1                   2
# 4            0   2539329        1             1                   2
# 5            1   2398795        1             2                   3
# 6            1   2398795        1             2                   3
# 7            1   2398795        1             2                   3
# 8            1   2398795        1             2                   3
# 9            1   2398795        1             2                   3
# 10           1   2398795        1             2                   3
# 11           2    473747        1             3                   3
# 12           2    473747        1             3                   3
# ...

# %%
df_prods_checked.head(20)
# Out:
#     Unnamed: 0  product_id                                       product_name  \
# 0            0           1                         Chocolate Sandwich Cookies
# 1            1           2                                   All-Seasons Salt
# 2            2           3               Robust Golden Unsweetened Oolong Tea
# 3            3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4            4           5                          Green Chile Anytime Sauce
# 5            5           6                                       Dry Nose Oil
# 6            6           7                     Pure Coconut Water With Orange
# 7            7           8                  Cut Russet Potatoes Steam N' Mash
# 8            8           9                  Light Strawberry Blueberry Yogurt
# 9            9          10     Sparkling Orange Juice & Prickly Pear Beverage
# 10          10          11                                  Peach Mango Juice
# ...

# %%
df_prods_checked.shape
# Out:
# (49693, 6)

# %% [markdown]
# # 4. Cleaning the datasets

# %%
# removing _merge column to be able to merge again
orders_products_combined = orders_products_combined.drop(columns = ['Unnamed: 0', '_merge'])

# %% [markdown]
# # 5. Merging the datasets

# %%
#Merge data frames base on product_id
df_merge_orders_prods = orders_products_combined.merge(df_prods_checked, on = 'product_id', indicator = True)

# %%
df_merge_orders_prods.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# # 6. Exporting the dataset

# %%
#Exporting data
df_merge_orders_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
