# %% [markdown]
# # Contents
# ## 1. Importing Libraries
# ## 2. Importing Data Frames
# ## 3. Checking Datasets
# ## 4. Merging the Datasets
# ## 5. Exporting the new dataset

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing Data Frames

# %%
# Creating the path for the data
path = r'C:\Users\sdaon\Documents\Instacart Basket Analysis'

# %%
# Importing orders data
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
# Importing products data
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_ords_prior = pd.read_csv(os.path.join(path, 'order_products_prior', 'order_products__prior.csv'), index_col =False)

# %% [markdown]
# # 3. Checking Datasets

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %% [markdown]
# # 4. Merging the Datasets

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head(20)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            0   2539329        1             1                   2
# 2            0   2539329        1             1                   2
# 3            0   2539329        1             1                   2
# 4            0   2539329        1             1                   2
# 5            1   2398795        1             2                   3
# 6            1   2398795        1             2                   3
# 7            1   2398795        1             2                   3
# 8            1   2398795        1             2                   3
# 9            1   2398795        1             2                   3
# 10           1   2398795        1             2                   3
# 11           2    473747        1             3                   3
# 12           2    473747        1             3                   3
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # 5. Exporting the new dataset

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
